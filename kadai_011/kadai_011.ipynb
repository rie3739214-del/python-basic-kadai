# %%
planets = ["水星", "金星", "地球", "火星", "木星", "土星", "天王星", "海王星", "冥王星"]

for planet in planets:
    print(planet)
# Out:
# 水星
# 金星
# 地球
# 火星
# 木星
# 土星
# 天王星
# 海王星
# 冥王星

# %%
planets = ["水星", "金星", "地球", "火星", "木星", "土星", "天王星", "海王星", "冥王星"]

i = 0
while i < len(planets):
    print(planets[i])
    i += 1
# Out:
# 水星
# 金星
# 地球
# 火星
# 木星
# 土星
# 天王星
# 海王星
# 冥王星
